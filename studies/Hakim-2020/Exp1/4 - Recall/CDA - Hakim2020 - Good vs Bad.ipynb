# %% [markdown]
# # Reproducing Hakim CDA Study (2020) - G vs B
#
# ### Notes

# %%
import numpy as np
import pandas as pd
import glob
import pickle
import copy

import mne
from mne import Epochs, pick_channels, find_events
from mne.io import read_raw_brainvision

from scipy.io import loadmat

import os
import sys
sys.path.append('/Users/nick/Documents/PhD/CLCT/reprod/studies/Hakim-2020/')
from events import get_specific_events, get_epochs, get_CDA, prep_report, fill_report, get_report, checksum

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 1. Prep Data

# %%
#==================================================================
# General Variables
#==================================================================
triggers = dict();

triggers['int'] = [21, 22] 
triggers['no_int'] = [11, 12]

triggers['left'] = [12, 22]  #[11, 21]
triggers['right'] = [11, 21] #[12, 22]

triggers['good'] = [91]
triggers['bad'] = [90]

# Labels
conds = ['int', 'no_int']
sides = ['left', 'right']
perfs = ['good', 'bad']

# CDA Channels
chan_right = ['PO8']
chan_left = ['PO7']

# Epoc Information
epoch_length = 3.65
epoch_tmin = -0.2
baseline_corr = (-0.2, 0)

# CDA main variable & Reports
cda_dict = dict()
report = prep_report(conds, sides, perfs)

#==================================================================
# Main Loop - Loading All Files & Extract CDAs.
#==================================================================
directory_path = '/Volumes/Nick - Data/CDA Datasets/Hakim 2020/Experiment 1/EegData/'

eegfiles = [os.path.join(dirpath, f)
    for dirpath, dirnames, files in os.walk(directory_path)
    for f in files if f.endswith('.vhdr')]

for filepath in eegfiles:
    filename = filepath[filepath.rfind('/')+1:]
    print('Processing: ' + filename + '...')

    # ------------------------
    # 1. -- Load File --
    # ------------------------
    raw = read_raw_brainvision(filepath, preload=True)
    
    # ------------------------
    # 2. -- Preprocessing --
    # ------------------------
    # Resample
    preproc = raw.resample(500)

    # Filter
    preproc = preproc.filter(.1, 30., fir_design='firwin')

    # Get events
    events = mne.events_from_annotations(preproc)
    events = events[0]
    
    #preproc.plot(events=events[0], block=True, lowpass=40)

    # ------------------------
    # 3. -- Epochs --
    # ------------------------
    specific_events = get_specific_events(events, conds, sides, perfs, triggers)

    epochs_dict = get_epochs(preproc, specific_events, epoch_length, epoch_tmin, baseline_corr)

    # ------------------------
    # 4. - Report & Checksum -
    # ------------------------
    report = fill_report(report, filename, specific_events)
    report.at[filename, 'checksum'] = checksum(specific_events, epochs_dict)
    
    # ------------------------
    # 5. -- CDA --
    # ------------------------
    cda_dict[filename] = get_CDA(epochs_dict, conds, sides, perfs, chan_right, chan_left)

# Add time points to CDA for later use.
times = epochs_dict['int']['left']['good'].times

print('{} Subjects & {} Trials'.format(len(report), np.sum([report[cond].sum() for cond in conds])))
report
# Out:
# Processing: Int1_2017.vhdr...
# Extracting parameters from /Volumes/Nick - Data/CDA Datasets/Hakim 2020/Experiment 1/EegData/1/Int1_2017.vhdr...
# Setting channel info structure...
# Reading 0 ... 3477439  =      0.000 ...  6954.878 secs...
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Online software filter detected. Using software filter settings and ignoring hardware values
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Channels contain different highpass filters. Lowest (weakest) filter setting (0.00 Hz) will be stored.
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Channels contain different lowpass filters. Highest (weakest) filter setting (250.00 Hz, Nyquist limit) will be stored.
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Not setting positions of 3 misc channels found in montage:
# ['HEOG', 'VEOG', 'StimTrak']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = read_raw_brainvision(filepath, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.10
# - Lower transition bandwidth: 0.10 Hz (-6 dB cutoff frequency: 0.05 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 16501 samples (33.002 sec)
#
# Used Annotations descriptions: ['New Segment/', 'Stimulus/S 11', 'Stimulus/S 12', 'Stimulus/S 21', 'Stimulus/S 22', 'Stimulus/S 90', 'Stimulus/S 91', 'Stimulus/S100', 'Stimulus/S101', 'Stimulus/S102', 'Stimulus/S103', 'Stimulus/S104', 'Stimulus/S105', 'Stimulus/S106']
# ====================== EPOCHING ======================
# tmin:-0.2, tmax:3.65, baseline=(-0.2, 0)
# ---------- int-left-good -------------
# Not setting metadata
# Not setting metadata
# 95 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 95 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- int-left-bad -------------
# Not setting metadata
# Not setting metadata
# 55 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 55 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- int-right-good -------------
# Not setting metadata
# Not setting metadata
# 100 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 100 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- int-right-bad -------------
# Not setting metadata
# Not setting metadata
# 50 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 50 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-left-good -------------
# Not setting metadata
# Not setting metadata
# 319 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 319 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-left-bad -------------
# Not setting metadata
# Not setting metadata
# 131 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 131 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-right-good -------------
# Not setting metadata
# Not setting metadata
# 288 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 288 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-right-bad -------------
# Not setting metadata
# Not setting metadata
# 162 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 162 events and 1926 original time points ...
# 0 bad epochs dropped
# ====================== /EPOCHING ======================
# Verifying Checksum (events vs epochs)...
# Checksum all good!
# Processing: 10_Int1_2017.vhdr...
# Extracting parameters from /Volumes/Nick - Data/CDA Datasets/Hakim 2020/Experiment 1/EegData/10/10_Int1_2017.vhdr...
# Setting channel info structure...
# Reading 0 ... 2942959  =      0.000 ...  5885.918 secs...
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: No coordinate information found for channels ['HEOG', 'VEOG', 'StimTrak']. Setting channel types to misc. To avoid this warning, set channel types explicitly.
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Online software filter detected. Using software filter settings and ignoring hardware values
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Channels contain different highpass filters. Lowest (weakest) filter setting (0.00 Hz) will be stored.
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Channels contain different lowpass filters. Highest (weakest) filter setting (250.00 Hz, Nyquist limit) will be stored.
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Not setting positions of 3 misc channels found in montage:
# ['HEOG', 'VEOG', 'StimTrak']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = read_raw_brainvision(filepath, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.10
# - Lower transition bandwidth: 0.10 Hz (-6 dB cutoff frequency: 0.05 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 16501 samples (33.002 sec)
#
# Used Annotations descriptions: ['New Segment/', 'Stimulus/S 11', 'Stimulus/S 12', 'Stimulus/S 21', 'Stimulus/S 22', 'Stimulus/S 90', 'Stimulus/S 91', 'Stimulus/S100', 'Stimulus/S101', 'Stimulus/S102', 'Stimulus/S103', 'Stimulus/S104', 'Stimulus/S105', 'Stimulus/S106']
# ====================== EPOCHING ======================
# tmin:-0.2, tmax:3.65, baseline=(-0.2, 0)
# ---------- int-left-good -------------
# Not setting metadata
# Not setting metadata
# 82 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 82 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- int-left-bad -------------
# Not setting metadata
# Not setting metadata
# 68 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 68 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- int-right-good -------------
# Not setting metadata
# Not setting metadata
# 81 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 81 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- int-right-bad -------------
# Not setting metadata
# Not setting metadata
# 69 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 69 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-left-good -------------
# Not setting metadata
# Not setting metadata
# 261 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 261 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-left-bad -------------
# Not setting metadata
# Not setting metadata
# 189 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 189 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-right-good -------------
# Not setting metadata
# Not setting metadata
# 258 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 258 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-right-bad -------------
# Not setting metadata
# Not setting metadata
# 192 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 192 events and 1926 original time points ...
# 0 bad epochs dropped
# ====================== /EPOCHING ======================
# Verifying Checksum (events vs epochs)...
# Checksum all good!
# Processing: 11_Int1_2017.vhdr...
# Extracting parameters from /Volumes/Nick - Data/CDA Datasets/Hakim 2020/Experiment 1/EegData/11/11_Int1_2017.vhdr...
# Setting channel info structure...
# Reading 0 ... 3369379  =      0.000 ...  6738.758 secs...
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Online software filter detected. Using software filter settings and ignoring hardware values
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Channels contain different highpass filters. Lowest (weakest) filter setting (0.00 Hz) will be stored.
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Channels contain different lowpass filters. Highest (weakest) filter setting (250.00 Hz, Nyquist limit) will be stored.
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Not setting positions of 3 misc channels found in montage:
# ['HEOG', 'VEOG', 'StimTrak']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = read_raw_brainvision(filepath, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.10
# - Lower transition bandwidth: 0.10 Hz (-6 dB cutoff frequency: 0.05 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 16501 samples (33.002 sec)
#
# Used Annotations descriptions: ['New Segment/', 'Stimulus/S 11', 'Stimulus/S 12', 'Stimulus/S 21', 'Stimulus/S 22', 'Stimulus/S 90', 'Stimulus/S 91', 'Stimulus/S100', 'Stimulus/S101', 'Stimulus/S102', 'Stimulus/S103', 'Stimulus/S104', 'Stimulus/S105', 'Stimulus/S106']
# ====================== EPOCHING ======================
# tmin:-0.2, tmax:3.65, baseline=(-0.2, 0)
# ---------- int-left-good -------------
# Not setting metadata
# Not setting metadata
# 84 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 84 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- int-left-bad -------------
# Not setting metadata
# Not setting metadata
# 66 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 66 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- int-right-good -------------
# Not setting metadata
# Not setting metadata
# 95 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 95 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- int-right-bad -------------
# Not setting metadata
# Not setting metadata
# 55 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 55 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-left-good -------------
# Not setting metadata
# Not setting metadata
# 305 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 305 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-left-bad -------------
# Not setting metadata
# Not setting metadata
# 145 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 145 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-right-good -------------
# Not setting metadata
# Not setting metadata
# 305 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 305 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-right-bad -------------
# Not setting metadata
# Not setting metadata
# 145 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 145 events and 1926 original time points ...
# 0 bad epochs dropped
# ====================== /EPOCHING ======================
# Verifying Checksum (events vs epochs)...
# Checksum all good!
# Processing: 12_Int1_2017.vhdr...
# Extracting parameters from /Volumes/Nick - Data/CDA Datasets/Hakim 2020/Experiment 1/EegData/12/12_Int1_2017.vhdr...
# Setting channel info structure...
# Reading 0 ... 3765759  =      0.000 ...  7531.518 secs...
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: No coordinate information found for channels ['HEOG', 'VEOG', 'StimTrak']. Setting channel types to misc. To avoid this warning, set channel types explicitly.
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Online software filter detected. Using software filter settings and ignoring hardware values
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Channels contain different highpass filters. Lowest (weakest) filter setting (0.00 Hz) will be stored.
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Channels contain different lowpass filters. Highest (weakest) filter setting (250.00 Hz, Nyquist limit) will be stored.
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Not setting positions of 3 misc channels found in montage:
# ['HEOG', 'VEOG', 'StimTrak']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = read_raw_brainvision(filepath, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.10
# - Lower transition bandwidth: 0.10 Hz (-6 dB cutoff frequency: 0.05 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 16501 samples (33.002 sec)
#
# Used Annotations descriptions: ['New Segment/', 'Stimulus/S 11', 'Stimulus/S 12', 'Stimulus/S 21', 'Stimulus/S 22', 'Stimulus/S 90', 'Stimulus/S 91', 'Stimulus/S100', 'Stimulus/S101', 'Stimulus/S102', 'Stimulus/S103', 'Stimulus/S104', 'Stimulus/S105', 'Stimulus/S106']
# ====================== EPOCHING ======================
# tmin:-0.2, tmax:3.65, baseline=(-0.2, 0)
# ---------- int-left-good -------------
# Not setting metadata
# Not setting metadata
# 94 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 94 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- int-left-bad -------------
# Not setting metadata
# Not setting metadata
# 56 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 56 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- int-right-good -------------
# Not setting metadata
# Not setting metadata
# 94 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 94 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- int-right-bad -------------
# Not setting metadata
# Not setting metadata
# 56 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 56 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-left-good -------------
# Not setting metadata
# Not setting metadata
# 304 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 304 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-left-bad -------------
# Not setting metadata
# Not setting metadata
# 146 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 146 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-right-good -------------
# Not setting metadata
# Not setting metadata
# 312 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 312 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-right-bad -------------
# Not setting metadata
# Not setting metadata
# 138 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 138 events and 1926 original time points ...
# 0 bad epochs dropped
# ====================== /EPOCHING ======================
# Verifying Checksum (events vs epochs)...
# Checksum all good!
# Processing: 13_Int1_2017.vhdr...
# Extracting parameters from /Volumes/Nick - Data/CDA Datasets/Hakim 2020/Experiment 1/EegData/13/13_Int1_2017.vhdr...
# Setting channel info structure...
# Reading 0 ... 3772249  =      0.000 ...  7544.498 secs...
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Online software filter detected. Using software filter settings and ignoring hardware values
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Channels contain different highpass filters. Lowest (weakest) filter setting (0.00 Hz) will be stored.
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Channels contain different lowpass filters. Highest (weakest) filter setting (250.00 Hz, Nyquist limit) will be stored.
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Not setting positions of 3 misc channels found in montage:
# ['HEOG', 'VEOG', 'StimTrak']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = read_raw_brainvision(filepath, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.10
# - Lower transition bandwidth: 0.10 Hz (-6 dB cutoff frequency: 0.05 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 16501 samples (33.002 sec)
#
# Used Annotations descriptions: ['New Segment/', 'Stimulus/S 11', 'Stimulus/S 12', 'Stimulus/S 21', 'Stimulus/S 22', 'Stimulus/S 90', 'Stimulus/S 91', 'Stimulus/S100', 'Stimulus/S101', 'Stimulus/S102', 'Stimulus/S103', 'Stimulus/S104', 'Stimulus/S105', 'Stimulus/S106']
# ====================== EPOCHING ======================
# tmin:-0.2, tmax:3.65, baseline=(-0.2, 0)
# ---------- int-left-good -------------
# Not setting metadata
# Not setting metadata
# 87 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 87 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- int-left-bad -------------
# Not setting metadata
# Not setting metadata
# 63 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 63 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- int-right-good -------------
# Not setting metadata
# Not setting metadata
# 81 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 81 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- int-right-bad -------------
# Not setting metadata
# Not setting metadata
# 69 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 69 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-left-good -------------
# Not setting metadata
# Not setting metadata
# 262 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 262 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-left-bad -------------
# Not setting metadata
# Not setting metadata
# 188 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 188 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-right-good -------------
# Not setting metadata
# Not setting metadata
# 255 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 255 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-right-bad -------------
# Not setting metadata
# Not setting metadata
# 195 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 195 events and 1926 original time points ...
# 0 bad epochs dropped
# ====================== /EPOCHING ======================
# Verifying Checksum (events vs epochs)...
# Checksum all good!
# Processing: 14_Int1_2017.vhdr...
# Extracting parameters from /Volumes/Nick - Data/CDA Datasets/Hakim 2020/Experiment 1/EegData/14/14_Int1_2017.vhdr...
# Setting channel info structure...
# Reading 0 ... 3486759  =      0.000 ...  6973.518 secs...
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Online software filter detected. Using software filter settings and ignoring hardware values
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Channels contain different highpass filters. Lowest (weakest) filter setting (0.00 Hz) will be stored.
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Channels contain different lowpass filters. Highest (weakest) filter setting (250.00 Hz, Nyquist limit) will be stored.
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Not setting positions of 3 misc channels found in montage:
# ['HEOG', 'VEOG', 'StimTrak']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = read_raw_brainvision(filepath, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.10
# - Lower transition bandwidth: 0.10 Hz (-6 dB cutoff frequency: 0.05 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 16501 samples (33.002 sec)
#
# Used Annotations descriptions: ['New Segment/', 'Stimulus/S 11', 'Stimulus/S 12', 'Stimulus/S 21', 'Stimulus/S 22', 'Stimulus/S 90', 'Stimulus/S 91', 'Stimulus/S100', 'Stimulus/S101', 'Stimulus/S102', 'Stimulus/S103', 'Stimulus/S104', 'Stimulus/S105', 'Stimulus/S106']
# ====================== EPOCHING ======================
# tmin:-0.2, tmax:3.65, baseline=(-0.2, 0)
# ---------- int-left-good -------------
# Not setting metadata
# Not setting metadata
# 84 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 84 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- int-left-bad -------------
# Not setting metadata
# Not setting metadata
# 66 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 66 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- int-right-good -------------
# Not setting metadata
# Not setting metadata
# 80 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 80 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- int-right-bad -------------
# Not setting metadata
# Not setting metadata
# 70 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 70 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-left-good -------------
# Not setting metadata
# Not setting metadata
# 299 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 299 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-left-bad -------------
# Not setting metadata
# Not setting metadata
# 151 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 151 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-right-good -------------
# Not setting metadata
# Not setting metadata
# 289 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 289 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-right-bad -------------
# Not setting metadata
# Not setting metadata
# 161 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 161 events and 1926 original time points ...
# 0 bad epochs dropped
# ====================== /EPOCHING ======================
# Verifying Checksum (events vs epochs)...
# Checksum all good!
# Processing: 15_Int1_2017.vhdr...
# Extracting parameters from /Volumes/Nick - Data/CDA Datasets/Hakim 2020/Experiment 1/EegData/15/15_Int1_2017.vhdr...
# Setting channel info structure...
# Reading 0 ... 3661579  =      0.000 ...  7323.158 secs...
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: No coordinate information found for channels ['HEOG', 'VEOG', 'StimTrak']. Setting channel types to misc. To avoid this warning, set channel types explicitly.
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Online software filter detected. Using software filter settings and ignoring hardware values
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Channels contain different highpass filters. Lowest (weakest) filter setting (0.00 Hz) will be stored.
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Channels contain different lowpass filters. Highest (weakest) filter setting (250.00 Hz, Nyquist limit) will be stored.
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Not setting positions of 3 misc channels found in montage:
# ['HEOG', 'VEOG', 'StimTrak']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = read_raw_brainvision(filepath, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.10
# - Lower transition bandwidth: 0.10 Hz (-6 dB cutoff frequency: 0.05 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 16501 samples (33.002 sec)
#
# Used Annotations descriptions: ['New Segment/', 'Stimulus/S 11', 'Stimulus/S 12', 'Stimulus/S 21', 'Stimulus/S 22', 'Stimulus/S 90', 'Stimulus/S 91', 'Stimulus/S100', 'Stimulus/S101', 'Stimulus/S102', 'Stimulus/S103', 'Stimulus/S104', 'Stimulus/S105', 'Stimulus/S106']
# ====================== EPOCHING ======================
# tmin:-0.2, tmax:3.65, baseline=(-0.2, 0)
# ---------- int-left-good -------------
# Not setting metadata
# Not setting metadata
# 101 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 101 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- int-left-bad -------------
# Not setting metadata
# Not setting metadata
# 49 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 49 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- int-right-good -------------
# Not setting metadata
# Not setting metadata
# 102 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 102 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- int-right-bad -------------
# Not setting metadata
# Not setting metadata
# 48 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 48 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-left-good -------------
# Not setting metadata
# Not setting metadata
# 309 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 309 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-left-bad -------------
# Not setting metadata
# Not setting metadata
# 141 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 141 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-right-good -------------
# Not setting metadata
# Not setting metadata
# 321 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 321 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-right-bad -------------
# Not setting metadata
# Not setting metadata
# 129 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 129 events and 1926 original time points ...
# 0 bad epochs dropped
# ====================== /EPOCHING ======================
# Verifying Checksum (events vs epochs)...
# Checksum all good!
# Processing: 16_Int1_2017.vhdr...
# Extracting parameters from /Volumes/Nick - Data/CDA Datasets/Hakim 2020/Experiment 1/EegData/16/16_Int1_2017.vhdr...
# Setting channel info structure...
# Reading 0 ... 4787459  =      0.000 ...  9574.918 secs...
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Online software filter detected. Using software filter settings and ignoring hardware values
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Channels contain different highpass filters. Lowest (weakest) filter setting (0.00 Hz) will be stored.
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Channels contain different lowpass filters. Highest (weakest) filter setting (250.00 Hz, Nyquist limit) will be stored.
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Not setting positions of 3 misc channels found in montage:
# ['HEOG', 'VEOG', 'StimTrak']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = read_raw_brainvision(filepath, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.10
# - Lower transition bandwidth: 0.10 Hz (-6 dB cutoff frequency: 0.05 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 16501 samples (33.002 sec)
#
# Used Annotations descriptions: ['New Segment/', 'Stimulus/S 11', 'Stimulus/S 12', 'Stimulus/S 21', 'Stimulus/S 22', 'Stimulus/S 90', 'Stimulus/S 91', 'Stimulus/S100', 'Stimulus/S101', 'Stimulus/S102', 'Stimulus/S103', 'Stimulus/S104', 'Stimulus/S105', 'Stimulus/S106']
# ====================== EPOCHING ======================
# tmin:-0.2, tmax:3.65, baseline=(-0.2, 0)
# ---------- int-left-good -------------
# Not setting metadata
# Not setting metadata
# 89 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 89 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- int-left-bad -------------
# Not setting metadata
# Not setting metadata
# 61 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 61 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- int-right-good -------------
# Not setting metadata
# Not setting metadata
# 96 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 96 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- int-right-bad -------------
# Not setting metadata
# Not setting metadata
# 54 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 54 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-left-good -------------
# Not setting metadata
# Not setting metadata
# 287 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 287 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-left-bad -------------
# Not setting metadata
# Not setting metadata
# 163 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 163 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-right-good -------------
# Not setting metadata
# Not setting metadata
# 260 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 260 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-right-bad -------------
# Not setting metadata
# Not setting metadata
# 190 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 190 events and 1926 original time points ...
# 0 bad epochs dropped
# ====================== /EPOCHING ======================
# Verifying Checksum (events vs epochs)...
# Checksum all good!
# Processing: 17_Int1_2017.vhdr...
# Extracting parameters from /Volumes/Nick - Data/CDA Datasets/Hakim 2020/Experiment 1/EegData/17/17_Int1_2017.vhdr...
# Setting channel info structure...
# Reading 0 ... 2836289  =      0.000 ...  5672.578 secs...
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: No coordinate information found for channels ['HEOG', 'VEOG', 'StimTrak']. Setting channel types to misc. To avoid this warning, set channel types explicitly.
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Online software filter detected. Using software filter settings and ignoring hardware values
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Channels contain different highpass filters. Lowest (weakest) filter setting (0.00 Hz) will be stored.
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Channels contain different lowpass filters. Highest (weakest) filter setting (250.00 Hz, Nyquist limit) will be stored.
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Not setting positions of 3 misc channels found in montage:
# ['HEOG', 'VEOG', 'StimTrak']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = read_raw_brainvision(filepath, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.10
# - Lower transition bandwidth: 0.10 Hz (-6 dB cutoff frequency: 0.05 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 16501 samples (33.002 sec)
#
# Used Annotations descriptions: ['New Segment/', 'Stimulus/S 11', 'Stimulus/S 12', 'Stimulus/S 21', 'Stimulus/S 22', 'Stimulus/S 90', 'Stimulus/S 91', 'Stimulus/S100', 'Stimulus/S101', 'Stimulus/S102', 'Stimulus/S103', 'Stimulus/S104', 'Stimulus/S105', 'Stimulus/S106']
# ====================== EPOCHING ======================
# tmin:-0.2, tmax:3.65, baseline=(-0.2, 0)
# ---------- int-left-good -------------
# Not setting metadata
# Not setting metadata
# 106 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 106 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- int-left-bad -------------
# Not setting metadata
# Not setting metadata
# 44 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 44 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- int-right-good -------------
# Not setting metadata
# Not setting metadata
# 90 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 90 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- int-right-bad -------------
# Not setting metadata
# Not setting metadata
# 60 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 60 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-left-good -------------
# Not setting metadata
# Not setting metadata
# 288 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 288 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-left-bad -------------
# Not setting metadata
# Not setting metadata
# 162 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 162 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-right-good -------------
# Not setting metadata
# Not setting metadata
# 280 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 280 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-right-bad -------------
# Not setting metadata
# Not setting metadata
# 170 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 170 events and 1926 original time points ...
# 0 bad epochs dropped
# ====================== /EPOCHING ======================
# Verifying Checksum (events vs epochs)...
# Checksum all good!
# Processing: 18_Int1_2017.vhdr...
# Extracting parameters from /Volumes/Nick - Data/CDA Datasets/Hakim 2020/Experiment 1/EegData/18/18_Int1_2017.vhdr...
# Setting channel info structure...
# Reading 0 ... 3096459  =      0.000 ...  6192.918 secs...
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: No coordinate information found for channels ['HEOG', 'VEOG', 'StimTrak']. Setting channel types to misc. To avoid this warning, set channel types explicitly.
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Online software filter detected. Using software filter settings and ignoring hardware values
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Channels contain different highpass filters. Lowest (weakest) filter setting (0.00 Hz) will be stored.
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Channels contain different lowpass filters. Highest (weakest) filter setting (250.00 Hz, Nyquist limit) will be stored.
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Not setting positions of 3 misc channels found in montage:
# ['HEOG', 'VEOG', 'StimTrak']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = read_raw_brainvision(filepath, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.10
# - Lower transition bandwidth: 0.10 Hz (-6 dB cutoff frequency: 0.05 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 16501 samples (33.002 sec)
#
# Used Annotations descriptions: ['New Segment/', 'Stimulus/S 11', 'Stimulus/S 12', 'Stimulus/S 21', 'Stimulus/S 22', 'Stimulus/S 90', 'Stimulus/S 91', 'Stimulus/S100', 'Stimulus/S101', 'Stimulus/S102', 'Stimulus/S103', 'Stimulus/S104', 'Stimulus/S105', 'Stimulus/S106']
# ====================== EPOCHING ======================
# tmin:-0.2, tmax:3.65, baseline=(-0.2, 0)
# ---------- int-left-good -------------
# Not setting metadata
# Not setting metadata
# 86 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 86 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- int-left-bad -------------
# Not setting metadata
# Not setting metadata
# 64 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 64 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- int-right-good -------------
# Not setting metadata
# Not setting metadata
# 94 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 94 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- int-right-bad -------------
# Not setting metadata
# Not setting metadata
# 56 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 56 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-left-good -------------
# Not setting metadata
# Not setting metadata
# 310 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 310 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-left-bad -------------
# Not setting metadata
# Not setting metadata
# 140 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 140 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-right-good -------------
# Not setting metadata
# Not setting metadata
# 307 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 307 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-right-bad -------------
# Not setting metadata
# Not setting metadata
# 143 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 143 events and 1926 original time points ...
# 0 bad epochs dropped
# ====================== /EPOCHING ======================
# Verifying Checksum (events vs epochs)...
# Checksum all good!
# Processing: 19_Int1_2017.vhdr...
# Extracting parameters from /Volumes/Nick - Data/CDA Datasets/Hakim 2020/Experiment 1/EegData/19/19_Int1_2017.vhdr...
# Setting channel info structure...
# Reading 0 ... 3365429  =      0.000 ...  6730.858 secs...
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: No coordinate information found for channels ['HEOG', 'VEOG', 'StimTrak']. Setting channel types to misc. To avoid this warning, set channel types explicitly.
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Online software filter detected. Using software filter settings and ignoring hardware values
# ...
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Channels contain different highpass filters. Lowest (weakest) filter setting (0.00 Hz) will be stored.
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Channels contain different lowpass filters. Highest (weakest) filter setting (250.00 Hz, Nyquist limit) will be stored.
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Not setting positions of 3 misc channels found in montage:
# ['HEOG', 'VEOG', 'StimTrak']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = read_raw_brainvision(filepath, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.10
# - Lower transition bandwidth: 0.10 Hz (-6 dB cutoff frequency: 0.05 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 16501 samples (33.002 sec)
#
# Used Annotations descriptions: ['New Segment/', 'Stimulus/S 11', 'Stimulus/S 12', 'Stimulus/S 21', 'Stimulus/S 22', 'Stimulus/S 90', 'Stimulus/S 91', 'Stimulus/S100', 'Stimulus/S101', 'Stimulus/S102', 'Stimulus/S103', 'Stimulus/S104', 'Stimulus/S105', 'Stimulus/S106']
# ====================== EPOCHING ======================
# tmin:-0.2, tmax:3.65, baseline=(-0.2, 0)
# ---------- int-left-good -------------
# Not setting metadata
# Not setting metadata
# 97 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 97 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- int-left-bad -------------
# Not setting metadata
# Not setting metadata
# 53 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 53 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- int-right-good -------------
# Not setting metadata
# Not setting metadata
# 97 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 97 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- int-right-bad -------------
# Not setting metadata
# Not setting metadata
# 53 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 53 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-left-good -------------
# Not setting metadata
# Not setting metadata
# 278 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 278 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-left-bad -------------
# Not setting metadata
# Not setting metadata
# 172 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 172 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-right-good -------------
# Not setting metadata
# Not setting metadata
# 285 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 285 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-right-bad -------------
# Not setting metadata
# Not setting metadata
# 165 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 165 events and 1926 original time points ...
# 0 bad epochs dropped
# ====================== /EPOCHING ======================
# Verifying Checksum (events vs epochs)...
# Checksum all good!
# Processing: 9_Int1_2017.vhdr...
# Extracting parameters from /Volumes/Nick - Data/CDA Datasets/Hakim 2020/Experiment 1/EegData/9/9_Int1_2017.vhdr...
# Setting channel info structure...
# Reading 0 ... 3616269  =      0.000 ...  7232.538 secs...
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: No coordinate information found for channels ['HEOG', 'VEOG', 'StimTrak']. Setting channel types to misc. To avoid this warning, set channel types explicitly.
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Online software filter detected. Using software filter settings and ignoring hardware values
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Channels contain different highpass filters. Lowest (weakest) filter setting (0.00 Hz) will be stored.
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Channels contain different lowpass filters. Highest (weakest) filter setting (250.00 Hz, Nyquist limit) will be stored.
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_7539/349586793.py:49: RuntimeWarning: Not setting positions of 3 misc channels found in montage:
# ['HEOG', 'VEOG', 'StimTrak']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = read_raw_brainvision(filepath, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.10
# - Lower transition bandwidth: 0.10 Hz (-6 dB cutoff frequency: 0.05 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 16501 samples (33.002 sec)
#
# Used Annotations descriptions: ['New Segment/', 'Stimulus/S 11', 'Stimulus/S 12', 'Stimulus/S 21', 'Stimulus/S 22', 'Stimulus/S 90', 'Stimulus/S 91', 'Stimulus/S100', 'Stimulus/S101', 'Stimulus/S102', 'Stimulus/S103', 'Stimulus/S104', 'Stimulus/S105', 'Stimulus/S106']
# ====================== EPOCHING ======================
# tmin:-0.2, tmax:3.65, baseline=(-0.2, 0)
# ---------- int-left-good -------------
# Not setting metadata
# Not setting metadata
# 99 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 99 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- int-left-bad -------------
# Not setting metadata
# Not setting metadata
# 51 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 51 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- int-right-good -------------
# Not setting metadata
# Not setting metadata
# 97 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 97 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- int-right-bad -------------
# Not setting metadata
# Not setting metadata
# 53 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 53 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-left-good -------------
# Not setting metadata
# Not setting metadata
# 333 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 333 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-left-bad -------------
# Not setting metadata
# Not setting metadata
# 117 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 117 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-right-good -------------
# Not setting metadata
# Not setting metadata
# 326 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 326 events and 1926 original time points ...
# 0 bad epochs dropped
# ---------- no_int-right-bad -------------
# Not setting metadata
# Not setting metadata
# 124 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 124 events and 1926 original time points ...
# 0 bad epochs dropped
# ====================== /EPOCHING ======================
# Verifying Checksum (events vs epochs)...
# Checksum all good!
# 22 Subjects & 26400 Trials
#                    int no_int left right good  bad int-left int-left-good  \
# Int1_2017.vhdr     300    900  600   600  802  398      150            95
# 10_Int1_2017.vhdr  300    900  600   600  682  518      150            82
# 11_Int1_2017.vhdr  300    900  600   600  789  411      150            84
# 12_Int1_2017.vhdr  300    900  600   600  804  396      150            94
# 13_Int1_2017.vhdr  300    900  600   600  685  515      150            87
# 14_Int1_2017.vhdr  300    900  600   600  752  448      150            84
# 15_Int1_2017.vhdr  300    900  600   600  833  367      150           101
# 16_Int1_2017.vhdr  300    900  600   600  732  468      150            89
# 17_Int1_2017.vhdr  300    900  600   600  764  436      150           106
# 18_Int1_2017.vhdr  300    900  600   600  797  403      150            86
# 19_Int1_2017.vhdr  300    900  600   600  604  596      150            76
# 1b_Int1_2017.vhdr  300    900  600   600  587  613      150            71
# 2_Int1_2017.vhdr   300    900  600   600  778  422      150            89
# 20_Int1_2017.vhdr  300    900  600   600  896  304      150           105
# 21_Int1_2017.vhdr  300    900  600   600  673  527      150            83
# 3_Int1_2017.vhdr   300    900  600   600  711  489      150            86
# 4_Int1_2017.vhdr   300    900  600   600  655  545      150            86
# 5_Int1_2017.vhdr   300    900  600   600  700  500      150            80
# 6_Int1_2017.vhdr   300    900  600   600  671  529      150            80
# 7_Int1_2017.vhdr   300    900  600   600  768  432      150            95
# 8_Int1_2017.vhdr   300    900  600   600  757  443      150            97
# 9_Int1_2017.vhdr   300    900  600   600  855  345      150            99
#
#                   int-good int-left-bad  ... no_int-left no_int-left-good  \
# Int1_2017.vhdr         195           55  ...         450              319
# 10_Int1_2017.vhdr      163           68  ...         450              261
# 11_Int1_2017.vhdr      179           66  ...         450              305
# 12_Int1_2017.vhdr      188           56  ...         450              304
# 13_Int1_2017.vhdr      168           63  ...         450              262
# 14_Int1_2017.vhdr      164           66  ...         450              299
# 15_Int1_2017.vhdr      203           49  ...         450              309
# 16_Int1_2017.vhdr      185           61  ...         450              287
# 17_Int1_2017.vhdr      196           44  ...         450              288
# 18_Int1_2017.vhdr      180           64  ...         450              310
# 19_Int1_2017.vhdr      154           74  ...         450              219
# 1b_Int1_2017.vhdr      155           79  ...         450              205
# 2_Int1_2017.vhdr       185           61  ...         450              309
# 20_Int1_2017.vhdr      215           45  ...         450              335
# 21_Int1_2017.vhdr      155           67  ...         450              246
# 3_Int1_2017.vhdr       183           64  ...         450              264
# 4_Int1_2017.vhdr       166           64  ...         450              256
# 5_Int1_2017.vhdr       176           70  ...         450              254
# 6_Int1_2017.vhdr       161           70  ...         450              272
# 7_Int1_2017.vhdr       180           55  ...         450              301
# 8_Int1_2017.vhdr       194           53  ...         450              278
# 9_Int1_2017.vhdr       196           51  ...         450              333
#
#                   no_int-good no_int-left-bad no_int-bad no_int-right  \
# Int1_2017.vhdr            607             131        293          450
# 10_Int1_2017.vhdr         519             189        381          450
# 11_Int1_2017.vhdr         610             145        290          450
# 12_Int1_2017.vhdr         616             146        284          450
# 13_Int1_2017.vhdr         517             188        383          450
# 14_Int1_2017.vhdr         588             151        312          450
# 15_Int1_2017.vhdr         630             141        270          450
# 16_Int1_2017.vhdr         547             163        353          450
# 17_Int1_2017.vhdr         568             162        332          450
# 18_Int1_2017.vhdr         617             140        283          450
# 19_Int1_2017.vhdr         450             231        450          450
# 1b_Int1_2017.vhdr         432             245        468          450
# 2_Int1_2017.vhdr          593             141        307          450
# 20_Int1_2017.vhdr         681             115        219          450
# 21_Int1_2017.vhdr         518             204        382          450
# 3_Int1_2017.vhdr          528             186        372          450
# 4_Int1_2017.vhdr          489             194        411          450
# 5_Int1_2017.vhdr          524             196        376          450
# 6_Int1_2017.vhdr          510             178        390          450
# 7_Int1_2017.vhdr          588             149        312          450
# 8_Int1_2017.vhdr          563             172        337          450
# 9_Int1_2017.vhdr          659             117        241          450
#
#                   no_int-right-good no_int-right-bad checksum notes
# Int1_2017.vhdr                  288              162        1
# 10_Int1_2017.vhdr               258              192        1
# 11_Int1_2017.vhdr               305              145        1
# 12_Int1_2017.vhdr               312              138        1
# 13_Int1_2017.vhdr               255              195        1
# 14_Int1_2017.vhdr               289              161        1
# 15_Int1_2017.vhdr               321              129        1
# 16_Int1_2017.vhdr               260              190        1
# 17_Int1_2017.vhdr               280              170        1
# 18_Int1_2017.vhdr               307              143        1
# 19_Int1_2017.vhdr               231              219        1
# 1b_Int1_2017.vhdr               227              223        1
# 2_Int1_2017.vhdr                284              166        1
# 20_Int1_2017.vhdr               346              104        1
# 21_Int1_2017.vhdr               272              178        1
# 3_Int1_2017.vhdr                264              186        1
# 4_Int1_2017.vhdr                233              217        1
# 5_Int1_2017.vhdr                270              180        1
# 6_Int1_2017.vhdr                238              212        1
# 7_Int1_2017.vhdr                287              163        1
# 8_Int1_2017.vhdr                285              165        1
# 9_Int1_2017.vhdr                326              124        1
#
# [22 rows x 24 columns]

# %% [markdown]
# ## 4. Plot CDA Data - Grand CDA Average

# %%
cda_all = dict()

for cond in cda_dict[list(cda_dict.keys())[0]].keys():
    cda_all[cond] = dict()

    perf = 'good'
    for f in cda_dict.keys():
        ldict = cda_dict[f][cond]['left']
        rdict = cda_dict[f][cond]['right']
        if (perf in ldict.keys() and len(ldict[perf])) and (perf in rdict.keys() and len(rdict[perf])):
            cda_dict_cur = (cda_dict[f][cond]['left']['good'] + cda_dict[f][cond]['right']['good'])/2
            cda_all[cond] = np.vstack([cda_all[cond], cda_dict_cur]) if len(cda_all[cond]) else cda_dict_cur
        else:
            print("==== SKIPPED: 0 points! (File: {} - Cond: {})".format(str(f), str(cond)))

# %% [markdown]
# ## Final CDA figure from Hakim 2020

# %%
plt.figure(figsize=(15, 6), dpi=300)
plt.plot(times, cda_all['int'].mean(0), label='int')
plt.plot(times, cda_all['no_int'].mean(0), label='no_int')

plt.axvline(x=0, color='k', linestyle='--')
plt.axvline(x=1.65, color='k', linestyle='--')
plt.axhline(y=0, color='k', linestyle='-')
plt.gca().invert_yaxis()
plt.legend()
plt.ylabel('[μV]')
plt.xlabel('[s]')
plt.show()
#plt.savefig("./img/Gunseli-2019_CDA-reprod.jpg", dpi=300)
