# %% [markdown]
# # Reproducing Feldmann-Wustefel CDA Study (2018) Exp1 - G vs B
#
# ## Notes

# %%
import numpy as np
import glob
import pickle

import mne
from mne import Epochs, pick_channels, find_events
from mne.io import read_raw_brainvision

from scipy.io import loadmat

import sys
sys.path.append('/Users/nick/Documents/PhD/CLCT/reprod/studies/Feldmann-Wustefeld-2018/')
from events import get_specific_events, get_epochs, get_CDA, prep_report, fill_report, get_report, checksum

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 1. Prep Data

# %%
#==================================================================
# General Variables
#==================================================================
triggers = dict();

triggers['1+3_same'] = [111, 112] 
triggers['2+2_same'] = [121, 122]
triggers['3+1_same'] = [131, 132]
triggers['1+3_diff'] = [141, 142] 
triggers['2+2_diff'] = [151, 152]
triggers['3+1_diff'] = [161, 162]

triggers['right'] = [111, 121, 131, 141, 151, 161]
triggers['left'] = [112, 122, 132, 142, 152, 162]

triggers['all'] = [111, 121, 131, 141, 151, 161, 112, 122, 132, 142, 152, 162]

# Good & Bad in Behav file! (no hardware trigger)
# --------------------------

# Labels
conds = ['1+3_same', '2+2_same', '3+1_same', '1+3_diff', '2+2_diff', '3+1_diff']
sides = ['left', 'right']
perfs = ['good', 'bad']

# CDA Channels
chan_right = ['PO8']
chan_left = ['PO7']

# Epochs information
epoch_length = 3.5
epoch_tmin = -0.2
baseline_corr = (-0.2, 0)

# CDA main variable!
cda_dict = dict()
report = prep_report(conds, sides, perfs)

#==================================================================
# Main Loop - Loading All Files & Extract CDAs.
#==================================================================
directory_path = '/Users/nick/Documents/PhD/CDA Datasets/Feldmann-Westefel 2018/AnalysisPipeline/Experiment1/'

for filepath in glob.iglob(directory_path + 'rawEEG/' + '*.vhdr'):
    filename = filepath[filepath.rfind('/')+1:]
    print('Processing: ' + filename + '...')

    # ------------------------
    # 1. -- Load File --
    # ------------------------
    raw = read_raw_brainvision(filepath, preload=True)

    # ------------------------
    # 2. -- Preprocessing --
    # ------------------------
    preproc = raw

    # In their study they re-reference to average. I skipped it for now.

    # Filter
    preproc = preproc.filter(.1, 30., fir_design='firwin')
    
    events = mne.events_from_annotations(preproc)
    #preproc.plot(events=events, block=True, lowpass=40)

    # ------------------------
    # 3. -- Epochs --
    # ------------------------
    #====================================
    # 1. Load Behav file to get ACC (accuracy: good/bad trials)
    # 2. Find 'clean' trials and sort them by triggers.
    # 3. Epochs
    # 4. Remove Baseline
    #====================================
    subject_str_idx = filename.rfind('.')
    subject_id = filename[subject_str_idx - 2: subject_str_idx]
    
    specific_events = get_specific_events(events[0], conds, sides, perfs, triggers, subject_id, experiment=1)

    epochs_dict = get_epochs(preproc, specific_events, epoch_length, epoch_tmin, baseline_corr)

    # ------------------------
    # 4. - Report & Checksum -
    # ------------------------
    report = fill_report(report, filename, specific_events)
    report.at[filename, 'checksum'] = checksum(specific_events, epochs_dict)
    
    # ------------------------
    # 5. -- CDA --
    # ------------------------
    cda_dict[filename] = get_CDA(epochs_dict, conds, sides, perfs, chan_right, chan_left)


# Add time points to CDA for later use.
times = epochs_dict['1+3_same']['left']['good'].times

# Print report
subreport = get_report(report, ['1+3_same', '2+2_same', '3+1_same', '1+3_diff', '2+2_diff', '3+1_diff'], ['left','right'], ['good', 'bad'], [])
report
# Out:
# Processing: Hudson_0017.vhdr...
# Extracting parameters from /Users/nick/Documents/PhD/CDA Datasets/Feldmann-Westefel 2018/AnalysisPipeline/Experiment1/rawEEG/Hudson_0017.vhdr...
# Setting channel info structure...
# Reading 0 ... 4845419  =      0.000 ...  4845.419 secs...
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_1380/2497651681.py:51: RuntimeWarning: No coordinate information found for channels ['HEOG', 'VEOG', 'StimTrak']. Setting channel types to misc. To avoid this warning, set channel types explicitly.
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_1380/2497651681.py:51: RuntimeWarning: Online software filter detected. Using software filter settings and ignoring hardware values
#   raw = read_raw_brainvision(filepath, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.10
# - Lower transition bandwidth: 0.10 Hz (-6 dB cutoff frequency: 0.05 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 33001 samples (33.001 sec)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_1380/2497651681.py:51: RuntimeWarning: Not setting positions of 3 misc channels found in montage:
# ['HEOG', 'VEOG', 'StimTrak']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = read_raw_brainvision(filepath, preload=True)
# Used Annotations descriptions: ['New Segment/', 'Stimulus/S  1', 'Stimulus/S  2', 'Stimulus/S 10', 'Stimulus/S 20', 'Stimulus/S 33', 'Stimulus/S 51', 'Stimulus/S 52', 'Stimulus/S 66', 'Stimulus/S 99', 'Stimulus/S111', 'Stimulus/S112', 'Stimulus/S116', 'Stimulus/S117', 'Stimulus/S121', 'Stimulus/S122', 'Stimulus/S126', 'Stimulus/S127', 'Stimulus/S131', 'Stimulus/S132', 'Stimulus/S136', 'Stimulus/S137', 'Stimulus/S141', 'Stimulus/S142', 'Stimulus/S146', 'Stimulus/S147', 'Stimulus/S151', 'Stimulus/S152', 'Stimulus/S156', 'Stimulus/S157', 'Stimulus/S161', 'Stimulus/S162', 'Stimulus/S166', 'Stimulus/S167']
# Nb Trials: 960 | Total Added: 960 | Total Skipped: 0
# ====================== EPOCHING ======================
# tmin:-0.2, tmax:3.5, baseline=(-0.2, 0)
# ---------- 1+3_same-left-good -------------
# Not setting metadata
# Not setting metadata
# 71 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 71 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_same-left-bad -------------
# Not setting metadata
# Not setting metadata
# 9 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 9 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_same-right-good -------------
# Not setting metadata
# Not setting metadata
# 70 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 70 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_same-right-bad -------------
# Not setting metadata
# Not setting metadata
# 10 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 10 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_same-left-good -------------
# Not setting metadata
# Not setting metadata
# 72 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 72 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_same-left-bad -------------
# Not setting metadata
# Not setting metadata
# 8 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 8 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_same-right-good -------------
# Not setting metadata
# Not setting metadata
# 72 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 72 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_same-right-bad -------------
# Not setting metadata
# Not setting metadata
# 8 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 8 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_same-left-good -------------
# Not setting metadata
# Not setting metadata
# 70 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 70 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_same-left-bad -------------
# Not setting metadata
# Not setting metadata
# 10 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 10 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_same-right-good -------------
# Not setting metadata
# Not setting metadata
# 69 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 69 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_same-right-bad -------------
# Not setting metadata
# Not setting metadata
# 11 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 11 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_diff-left-good -------------
# Not setting metadata
# Not setting metadata
# 77 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 77 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_diff-left-bad -------------
# Not setting metadata
# Not setting metadata
# 3 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 3 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_diff-right-good -------------
# Not setting metadata
# Not setting metadata
# 70 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 70 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_diff-right-bad -------------
# Not setting metadata
# Not setting metadata
# 10 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 10 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_diff-left-good -------------
# Not setting metadata
# Not setting metadata
# 71 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 71 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_diff-left-bad -------------
# Not setting metadata
# Not setting metadata
# 9 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 9 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_diff-right-good -------------
# Not setting metadata
# Not setting metadata
# 72 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 72 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_diff-right-bad -------------
# Not setting metadata
# Not setting metadata
# 8 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 8 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_diff-left-good -------------
# Not setting metadata
# Not setting metadata
# 68 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 68 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_diff-left-bad -------------
# Not setting metadata
# Not setting metadata
# 12 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 12 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_diff-right-good -------------
# Not setting metadata
# Not setting metadata
# 73 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 73 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_diff-right-bad -------------
# Not setting metadata
# Not setting metadata
# 7 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 7 events and 3701 original time points ...
# 0 bad epochs dropped
# ====================== /EPOCHING ======================
# Verifying Checksum (events vs epochs)...
# Checksum all good!
# Processing: Hudson_0021.vhdr...
# Extracting parameters from /Users/nick/Documents/PhD/CDA Datasets/Feldmann-Westefel 2018/AnalysisPipeline/Experiment1/rawEEG/Hudson_0021.vhdr...
# Setting channel info structure...
# Reading 0 ... 4767579  =      0.000 ...  4767.579 secs...
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_1380/2497651681.py:51: RuntimeWarning: No coordinate information found for channels ['HEOG', 'VEOG', 'StimTrak']. Setting channel types to misc. To avoid this warning, set channel types explicitly.
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_1380/2497651681.py:51: RuntimeWarning: Online software filter detected. Using software filter settings and ignoring hardware values
#   raw = read_raw_brainvision(filepath, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.10
# - Lower transition bandwidth: 0.10 Hz (-6 dB cutoff frequency: 0.05 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 33001 samples (33.001 sec)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_1380/2497651681.py:51: RuntimeWarning: Not setting positions of 3 misc channels found in montage:
# ['HEOG', 'VEOG', 'StimTrak']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = read_raw_brainvision(filepath, preload=True)
# Used Annotations descriptions: ['New Segment/', 'Stimulus/S  1', 'Stimulus/S  2', 'Stimulus/S 10', 'Stimulus/S 20', 'Stimulus/S 33', 'Stimulus/S 51', 'Stimulus/S 52', 'Stimulus/S 66', 'Stimulus/S 99', 'Stimulus/S111', 'Stimulus/S112', 'Stimulus/S116', 'Stimulus/S117', 'Stimulus/S121', 'Stimulus/S122', 'Stimulus/S126', 'Stimulus/S127', 'Stimulus/S131', 'Stimulus/S132', 'Stimulus/S136', 'Stimulus/S137', 'Stimulus/S141', 'Stimulus/S142', 'Stimulus/S146', 'Stimulus/S147', 'Stimulus/S151', 'Stimulus/S152', 'Stimulus/S156', 'Stimulus/S157', 'Stimulus/S161', 'Stimulus/S162', 'Stimulus/S166', 'Stimulus/S167']
# Nb Trials: 960 | Total Added: 960 | Total Skipped: 0
# ====================== EPOCHING ======================
# tmin:-0.2, tmax:3.5, baseline=(-0.2, 0)
# ---------- 1+3_same-left-good -------------
# Not setting metadata
# Not setting metadata
# 69 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 69 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_same-left-bad -------------
# Not setting metadata
# Not setting metadata
# 11 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 11 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_same-right-good -------------
# Not setting metadata
# Not setting metadata
# 75 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 75 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_same-right-bad -------------
# Not setting metadata
# Not setting metadata
# 5 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 5 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_same-left-good -------------
# Not setting metadata
# Not setting metadata
# 71 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 71 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_same-left-bad -------------
# Not setting metadata
# Not setting metadata
# 9 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 9 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_same-right-good -------------
# Not setting metadata
# Not setting metadata
# 70 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 70 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_same-right-bad -------------
# Not setting metadata
# Not setting metadata
# 10 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 10 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_same-left-good -------------
# Not setting metadata
# Not setting metadata
# 72 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 72 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_same-left-bad -------------
# Not setting metadata
# Not setting metadata
# 8 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 8 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_same-right-good -------------
# Not setting metadata
# Not setting metadata
# 72 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 72 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_same-right-bad -------------
# Not setting metadata
# Not setting metadata
# 8 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 8 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_diff-left-good -------------
# Not setting metadata
# Not setting metadata
# 66 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 66 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_diff-left-bad -------------
# Not setting metadata
# Not setting metadata
# 14 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 14 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_diff-right-good -------------
# Not setting metadata
# Not setting metadata
# 69 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 69 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_diff-right-bad -------------
# Not setting metadata
# Not setting metadata
# 11 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 11 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_diff-left-good -------------
# Not setting metadata
# Not setting metadata
# 67 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 67 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_diff-left-bad -------------
# Not setting metadata
# Not setting metadata
# 13 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 13 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_diff-right-good -------------
# Not setting metadata
# Not setting metadata
# 68 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 68 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_diff-right-bad -------------
# Not setting metadata
# Not setting metadata
# 12 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 12 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_diff-left-good -------------
# Not setting metadata
# Not setting metadata
# 71 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 71 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_diff-left-bad -------------
# Not setting metadata
# Not setting metadata
# 9 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 9 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_diff-right-good -------------
# Not setting metadata
# Not setting metadata
# 67 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 67 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_diff-right-bad -------------
# Not setting metadata
# Not setting metadata
# 13 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 13 events and 3701 original time points ...
# 0 bad epochs dropped
# ====================== /EPOCHING ======================
# Verifying Checksum (events vs epochs)...
# Checksum all good!
# Processing: Hudson_0020.vhdr...
# Extracting parameters from /Users/nick/Documents/PhD/CDA Datasets/Feldmann-Westefel 2018/AnalysisPipeline/Experiment1/rawEEG/Hudson_0020.vhdr...
# Setting channel info structure...
# Reading 0 ... 6487939  =      0.000 ...  6487.939 secs...
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_1380/2497651681.py:51: RuntimeWarning: No coordinate information found for channels ['HEOG', 'VEOG', 'StimTrak']. Setting channel types to misc. To avoid this warning, set channel types explicitly.
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_1380/2497651681.py:51: RuntimeWarning: Online software filter detected. Using software filter settings and ignoring hardware values
#   raw = read_raw_brainvision(filepath, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.10
# - Lower transition bandwidth: 0.10 Hz (-6 dB cutoff frequency: 0.05 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 33001 samples (33.001 sec)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_1380/2497651681.py:51: RuntimeWarning: Not setting positions of 3 misc channels found in montage:
# ['HEOG', 'VEOG', 'StimTrak']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = read_raw_brainvision(filepath, preload=True)
# Used Annotations descriptions: ['New Segment/', 'Stimulus/S  1', 'Stimulus/S  2', 'Stimulus/S 10', 'Stimulus/S 20', 'Stimulus/S 33', 'Stimulus/S 51', 'Stimulus/S 52', 'Stimulus/S 66', 'Stimulus/S 99', 'Stimulus/S111', 'Stimulus/S112', 'Stimulus/S116', 'Stimulus/S117', 'Stimulus/S121', 'Stimulus/S122', 'Stimulus/S126', 'Stimulus/S127', 'Stimulus/S131', 'Stimulus/S132', 'Stimulus/S136', 'Stimulus/S137', 'Stimulus/S141', 'Stimulus/S142', 'Stimulus/S146', 'Stimulus/S147', 'Stimulus/S151', 'Stimulus/S152', 'Stimulus/S156', 'Stimulus/S157', 'Stimulus/S161', 'Stimulus/S162', 'Stimulus/S166', 'Stimulus/S167']
# Nb Trials: 960 | Total Added: 960 | Total Skipped: 0
# ====================== EPOCHING ======================
# tmin:-0.2, tmax:3.5, baseline=(-0.2, 0)
# ---------- 1+3_same-left-good -------------
# Not setting metadata
# Not setting metadata
# 60 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 60 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_same-left-bad -------------
# Not setting metadata
# Not setting metadata
# 20 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 20 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_same-right-good -------------
# Not setting metadata
# Not setting metadata
# 67 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 67 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_same-right-bad -------------
# Not setting metadata
# Not setting metadata
# 13 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 13 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_same-left-good -------------
# Not setting metadata
# Not setting metadata
# 57 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 57 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_same-left-bad -------------
# Not setting metadata
# Not setting metadata
# 23 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 23 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_same-right-good -------------
# Not setting metadata
# Not setting metadata
# 61 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 61 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_same-right-bad -------------
# Not setting metadata
# Not setting metadata
# 19 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 19 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_same-left-good -------------
# Not setting metadata
# Not setting metadata
# 55 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 55 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_same-left-bad -------------
# Not setting metadata
# Not setting metadata
# 25 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 25 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_same-right-good -------------
# Not setting metadata
# Not setting metadata
# 60 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 60 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_same-right-bad -------------
# Not setting metadata
# Not setting metadata
# 20 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 20 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_diff-left-good -------------
# Not setting metadata
# Not setting metadata
# 52 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 52 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_diff-left-bad -------------
# Not setting metadata
# Not setting metadata
# 28 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 28 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_diff-right-good -------------
# Not setting metadata
# Not setting metadata
# 55 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 55 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_diff-right-bad -------------
# Not setting metadata
# Not setting metadata
# 25 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 25 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_diff-left-good -------------
# Not setting metadata
# Not setting metadata
# 61 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 61 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_diff-left-bad -------------
# Not setting metadata
# Not setting metadata
# 19 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 19 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_diff-right-good -------------
# Not setting metadata
# Not setting metadata
# 55 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 55 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_diff-right-bad -------------
# Not setting metadata
# Not setting metadata
# 25 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 25 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_diff-left-good -------------
# Not setting metadata
# Not setting metadata
# 55 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 55 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_diff-left-bad -------------
# Not setting metadata
# Not setting metadata
# 25 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 25 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_diff-right-good -------------
# Not setting metadata
# Not setting metadata
# 60 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 60 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_diff-right-bad -------------
# Not setting metadata
# Not setting metadata
# 20 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 20 events and 3701 original time points ...
# 0 bad epochs dropped
# ====================== /EPOCHING ======================
# Verifying Checksum (events vs epochs)...
# Checksum all good!
# Processing: Hudson_0016.vhdr...
# Extracting parameters from /Users/nick/Documents/PhD/CDA Datasets/Feldmann-Westefel 2018/AnalysisPipeline/Experiment1/rawEEG/Hudson_0016.vhdr...
# Setting channel info structure...
# Reading 0 ... 4879319  =      0.000 ...  4879.319 secs...
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_1380/2497651681.py:51: RuntimeWarning: No coordinate information found for channels ['HEOG', 'VEOG', 'StimTrak']. Setting channel types to misc. To avoid this warning, set channel types explicitly.
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_1380/2497651681.py:51: RuntimeWarning: Online software filter detected. Using software filter settings and ignoring hardware values
#   raw = read_raw_brainvision(filepath, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.10
# - Lower transition bandwidth: 0.10 Hz (-6 dB cutoff frequency: 0.05 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 33001 samples (33.001 sec)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_1380/2497651681.py:51: RuntimeWarning: Not setting positions of 3 misc channels found in montage:
# ['HEOG', 'VEOG', 'StimTrak']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = read_raw_brainvision(filepath, preload=True)
# Used Annotations descriptions: ['New Segment/', 'Stimulus/S  1', 'Stimulus/S  2', 'Stimulus/S 10', 'Stimulus/S 20', 'Stimulus/S 33', 'Stimulus/S 51', 'Stimulus/S 52', 'Stimulus/S 66', 'Stimulus/S 99', 'Stimulus/S111', 'Stimulus/S112', 'Stimulus/S116', 'Stimulus/S117', 'Stimulus/S121', 'Stimulus/S122', 'Stimulus/S126', 'Stimulus/S127', 'Stimulus/S131', 'Stimulus/S132', 'Stimulus/S136', 'Stimulus/S137', 'Stimulus/S141', 'Stimulus/S142', 'Stimulus/S146', 'Stimulus/S147', 'Stimulus/S151', 'Stimulus/S152', 'Stimulus/S156', 'Stimulus/S157', 'Stimulus/S161', 'Stimulus/S162', 'Stimulus/S166', 'Stimulus/S167']
# Nb Trials: 960 | Total Added: 960 | Total Skipped: 0
# ====================== EPOCHING ======================
# tmin:-0.2, tmax:3.5, baseline=(-0.2, 0)
# ---------- 1+3_same-left-good -------------
# Not setting metadata
# Not setting metadata
# 60 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 60 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_same-left-bad -------------
# Not setting metadata
# Not setting metadata
# 20 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 20 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_same-right-good -------------
# Not setting metadata
# Not setting metadata
# 55 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 55 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_same-right-bad -------------
# Not setting metadata
# Not setting metadata
# 25 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 25 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_same-left-good -------------
# Not setting metadata
# Not setting metadata
# 57 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 57 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_same-left-bad -------------
# Not setting metadata
# Not setting metadata
# 23 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 23 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_same-right-good -------------
# Not setting metadata
# Not setting metadata
# 58 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 58 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_same-right-bad -------------
# Not setting metadata
# Not setting metadata
# 22 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 22 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_same-left-good -------------
# Not setting metadata
# Not setting metadata
# 60 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 60 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_same-left-bad -------------
# Not setting metadata
# Not setting metadata
# 20 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 20 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_same-right-good -------------
# Not setting metadata
# Not setting metadata
# 54 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 54 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_same-right-bad -------------
# Not setting metadata
# Not setting metadata
# 26 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 26 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_diff-left-good -------------
# Not setting metadata
# Not setting metadata
# 55 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 55 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_diff-left-bad -------------
# Not setting metadata
# Not setting metadata
# 25 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 25 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_diff-right-good -------------
# Not setting metadata
# Not setting metadata
# 60 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 60 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_diff-right-bad -------------
# Not setting metadata
# Not setting metadata
# 20 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 20 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_diff-left-good -------------
# Not setting metadata
# Not setting metadata
# 65 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 65 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_diff-left-bad -------------
# Not setting metadata
# Not setting metadata
# 15 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 15 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_diff-right-good -------------
# Not setting metadata
# Not setting metadata
# 54 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 54 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_diff-right-bad -------------
# Not setting metadata
# Not setting metadata
# 26 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 26 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_diff-left-good -------------
# Not setting metadata
# Not setting metadata
# 56 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 56 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_diff-left-bad -------------
# Not setting metadata
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 24 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_diff-right-good -------------
# Not setting metadata
# Not setting metadata
# 60 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 60 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_diff-right-bad -------------
# Not setting metadata
# Not setting metadata
# 20 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 20 events and 3701 original time points ...
# 0 bad epochs dropped
# ====================== /EPOCHING ======================
# Verifying Checksum (events vs epochs)...
# Checksum all good!
# Processing: Hudson_0031.vhdr...
# Extracting parameters from /Users/nick/Documents/PhD/CDA Datasets/Feldmann-Westefel 2018/AnalysisPipeline/Experiment1/rawEEG/Hudson_0031.vhdr...
# Setting channel info structure...
# Reading 0 ... 6232459  =      0.000 ...  6232.459 secs...
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_1380/2497651681.py:51: RuntimeWarning: No coordinate information found for channels ['HEOG', 'VEOG', 'StimTrak']. Setting channel types to misc. To avoid this warning, set channel types explicitly.
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_1380/2497651681.py:51: RuntimeWarning: Online software filter detected. Using software filter settings and ignoring hardware values
#   raw = read_raw_brainvision(filepath, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.10
# - Lower transition bandwidth: 0.10 Hz (-6 dB cutoff frequency: 0.05 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 33001 samples (33.001 sec)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_1380/2497651681.py:51: RuntimeWarning: Not setting positions of 3 misc channels found in montage:
# ['HEOG', 'VEOG', 'StimTrak']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = read_raw_brainvision(filepath, preload=True)
# Used Annotations descriptions: ['New Segment/', 'Stimulus/S  1', 'Stimulus/S  2', 'Stimulus/S 10', 'Stimulus/S 20', 'Stimulus/S 33', 'Stimulus/S 51', 'Stimulus/S 52', 'Stimulus/S 66', 'Stimulus/S 99', 'Stimulus/S111', 'Stimulus/S112', 'Stimulus/S116', 'Stimulus/S117', 'Stimulus/S121', 'Stimulus/S122', 'Stimulus/S126', 'Stimulus/S127', 'Stimulus/S131', 'Stimulus/S132', 'Stimulus/S136', 'Stimulus/S137', 'Stimulus/S141', 'Stimulus/S142', 'Stimulus/S146', 'Stimulus/S147', 'Stimulus/S151', 'Stimulus/S152', 'Stimulus/S156', 'Stimulus/S157', 'Stimulus/S161', 'Stimulus/S162', 'Stimulus/S166', 'Stimulus/S167']
# Nb Trials: 960 | Total Added: 960 | Total Skipped: 0
# ====================== EPOCHING ======================
# tmin:-0.2, tmax:3.5, baseline=(-0.2, 0)
# ---------- 1+3_same-left-good -------------
# Not setting metadata
# Not setting metadata
# 61 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 61 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_same-left-bad -------------
# Not setting metadata
# Not setting metadata
# 19 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 19 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_same-right-good -------------
# Not setting metadata
# Not setting metadata
# 54 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 54 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_same-right-bad -------------
# Not setting metadata
# Not setting metadata
# 26 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 26 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_same-left-good -------------
# Not setting metadata
# Not setting metadata
# 67 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 67 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_same-left-bad -------------
# Not setting metadata
# Not setting metadata
# 13 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 13 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_same-right-good -------------
# Not setting metadata
# Not setting metadata
# 68 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 68 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_same-right-bad -------------
# Not setting metadata
# Not setting metadata
# 12 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 12 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_same-left-good -------------
# Not setting metadata
# Not setting metadata
# 61 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 61 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_same-left-bad -------------
# Not setting metadata
# Not setting metadata
# 19 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 19 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_same-right-good -------------
# Not setting metadata
# Not setting metadata
# 59 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 59 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_same-right-bad -------------
# Not setting metadata
# Not setting metadata
# 21 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 21 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_diff-left-good -------------
# Not setting metadata
# Not setting metadata
# 65 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 65 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_diff-left-bad -------------
# Not setting metadata
# Not setting metadata
# 15 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 15 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_diff-right-good -------------
# Not setting metadata
# Not setting metadata
# 51 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 51 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_diff-right-bad -------------
# Not setting metadata
# Not setting metadata
# 29 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 29 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_diff-left-good -------------
# Not setting metadata
# Not setting metadata
# 56 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 56 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_diff-left-bad -------------
# Not setting metadata
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 24 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_diff-right-good -------------
# Not setting metadata
# Not setting metadata
# 61 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 61 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_diff-right-bad -------------
# Not setting metadata
# Not setting metadata
# 19 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 19 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_diff-left-good -------------
# Not setting metadata
# Not setting metadata
# 60 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 60 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_diff-left-bad -------------
# Not setting metadata
# Not setting metadata
# 20 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 20 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_diff-right-good -------------
# Not setting metadata
# Not setting metadata
# 60 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 60 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_diff-right-bad -------------
# Not setting metadata
# Not setting metadata
# 20 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 20 events and 3701 original time points ...
# 0 bad epochs dropped
# ====================== /EPOCHING ======================
# Verifying Checksum (events vs epochs)...
# Checksum all good!
# Processing: Hudson_0027.vhdr...
# Extracting parameters from /Users/nick/Documents/PhD/CDA Datasets/Feldmann-Westefel 2018/AnalysisPipeline/Experiment1/rawEEG/Hudson_0027.vhdr...
# Setting channel info structure...
# Reading 0 ... 8433919  =      0.000 ...  8433.919 secs...
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_1380/2497651681.py:51: RuntimeWarning: No coordinate information found for channels ['HEOG', 'VEOG', 'StimTrak']. Setting channel types to misc. To avoid this warning, set channel types explicitly.
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_1380/2497651681.py:51: RuntimeWarning: Online software filter detected. Using software filter settings and ignoring hardware values
#   raw = read_raw_brainvision(filepath, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.10
# - Lower transition bandwidth: 0.10 Hz (-6 dB cutoff frequency: 0.05 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 33001 samples (33.001 sec)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_1380/2497651681.py:51: RuntimeWarning: Not setting positions of 3 misc channels found in montage:
# ['HEOG', 'VEOG', 'StimTrak']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = read_raw_brainvision(filepath, preload=True)
# Used Annotations descriptions: ['New Segment/', 'Stimulus/S  1', 'Stimulus/S  2', 'Stimulus/S 10', 'Stimulus/S 20', 'Stimulus/S 33', 'Stimulus/S 51', 'Stimulus/S 52', 'Stimulus/S 66', 'Stimulus/S 99', 'Stimulus/S111', 'Stimulus/S112', 'Stimulus/S116', 'Stimulus/S117', 'Stimulus/S121', 'Stimulus/S122', 'Stimulus/S126', 'Stimulus/S127', 'Stimulus/S131', 'Stimulus/S132', 'Stimulus/S136', 'Stimulus/S137', 'Stimulus/S141', 'Stimulus/S142', 'Stimulus/S146', 'Stimulus/S147', 'Stimulus/S151', 'Stimulus/S152', 'Stimulus/S156', 'Stimulus/S157', 'Stimulus/S161', 'Stimulus/S162', 'Stimulus/S166', 'Stimulus/S167']
# Nb Trials: 960 | Total Added: 960 | Total Skipped: 0
# ====================== EPOCHING ======================
# tmin:-0.2, tmax:3.5, baseline=(-0.2, 0)
# ---------- 1+3_same-left-good -------------
# Not setting metadata
# Not setting metadata
# 63 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 63 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_same-left-bad -------------
# Not setting metadata
# Not setting metadata
# ...
#   raw = read_raw_brainvision(filepath, preload=True)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_1380/2497651681.py:51: RuntimeWarning: Online software filter detected. Using software filter settings and ignoring hardware values
#   raw = read_raw_brainvision(filepath, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.10
# - Lower transition bandwidth: 0.10 Hz (-6 dB cutoff frequency: 0.05 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 33001 samples (33.001 sec)
# /var/folders/gn/5c249d_15xb7y6sdl7n8cn9m0000gn/T/ipykernel_1380/2497651681.py:51: RuntimeWarning: Not setting positions of 3 misc channels found in montage:
# ['HEOG', 'VEOG', 'StimTrak']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = read_raw_brainvision(filepath, preload=True)
# Used Annotations descriptions: ['New Segment/', 'Stimulus/S  1', 'Stimulus/S  2', 'Stimulus/S 10', 'Stimulus/S 20', 'Stimulus/S 33', 'Stimulus/S 51', 'Stimulus/S 52', 'Stimulus/S 66', 'Stimulus/S 99', 'Stimulus/S111', 'Stimulus/S112', 'Stimulus/S116', 'Stimulus/S117', 'Stimulus/S121', 'Stimulus/S122', 'Stimulus/S126', 'Stimulus/S127', 'Stimulus/S131', 'Stimulus/S132', 'Stimulus/S136', 'Stimulus/S137', 'Stimulus/S141', 'Stimulus/S142', 'Stimulus/S146', 'Stimulus/S147', 'Stimulus/S151', 'Stimulus/S152', 'Stimulus/S156', 'Stimulus/S157', 'Stimulus/S161', 'Stimulus/S162', 'Stimulus/S166', 'Stimulus/S167']
# Nb Trials: 960 | Total Added: 960 | Total Skipped: 0
# ====================== EPOCHING ======================
# tmin:-0.2, tmax:3.5, baseline=(-0.2, 0)
# ---------- 1+3_same-left-good -------------
# Not setting metadata
# Not setting metadata
# 54 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 54 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_same-left-bad -------------
# Not setting metadata
# Not setting metadata
# 26 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 26 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_same-right-good -------------
# Not setting metadata
# Not setting metadata
# 51 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 51 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_same-right-bad -------------
# Not setting metadata
# Not setting metadata
# 29 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 29 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_same-left-good -------------
# Not setting metadata
# Not setting metadata
# 65 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 65 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_same-left-bad -------------
# Not setting metadata
# Not setting metadata
# 15 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 15 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_same-right-good -------------
# Not setting metadata
# Not setting metadata
# 56 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 56 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_same-right-bad -------------
# Not setting metadata
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 24 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_same-left-good -------------
# Not setting metadata
# Not setting metadata
# 55 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 55 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_same-left-bad -------------
# Not setting metadata
# Not setting metadata
# 25 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 25 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_same-right-good -------------
# Not setting metadata
# Not setting metadata
# 60 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 60 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_same-right-bad -------------
# Not setting metadata
# Not setting metadata
# 20 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 20 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_diff-left-good -------------
# Not setting metadata
# Not setting metadata
# 58 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 58 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_diff-left-bad -------------
# Not setting metadata
# Not setting metadata
# 22 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 22 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_diff-right-good -------------
# Not setting metadata
# Not setting metadata
# 54 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 54 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 1+3_diff-right-bad -------------
# Not setting metadata
# Not setting metadata
# 26 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 26 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_diff-left-good -------------
# Not setting metadata
# Not setting metadata
# 55 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 55 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_diff-left-bad -------------
# Not setting metadata
# Not setting metadata
# 25 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 25 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_diff-right-good -------------
# Not setting metadata
# Not setting metadata
# 56 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 56 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 2+2_diff-right-bad -------------
# Not setting metadata
# Not setting metadata
# 24 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 24 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_diff-left-good -------------
# Not setting metadata
# Not setting metadata
# 52 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 52 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_diff-left-bad -------------
# Not setting metadata
# Not setting metadata
# 28 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 28 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_diff-right-good -------------
# Not setting metadata
# Not setting metadata
# 60 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 60 events and 3701 original time points ...
# 0 bad epochs dropped
# ---------- 3+1_diff-right-bad -------------
# Not setting metadata
# Not setting metadata
# 20 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 20 events and 3701 original time points ...
# 0 bad epochs dropped
# ====================== /EPOCHING ======================
# Verifying Checksum (events vs epochs)...
# Checksum all good!
#                  1+3_same 2+2_same 3+1_same 1+3_diff 2+2_diff 3+1_diff left  \
# Hudson_0017.vhdr      160      160      160      160      160      160  480
# Hudson_0021.vhdr      160      160      160      160      160      160  480
# Hudson_0020.vhdr      160      160      160      160      160      160  480
# Hudson_0016.vhdr      160      160      160      160      160      160  480
# Hudson_0031.vhdr      160      160      160      160      160      160  480
# Hudson_0027.vhdr      160      160      160      160      160      160  480
# Hudson_0026.vhdr       80       80       80       80       80       80  240
# Hudson_0030.vhdr      160      160      160      160      160      160  480
# Hudson_0025.vhdr      160      160      160      160      160      160  480
# Hudson_0033.vhdr      160      160      160      160      160      160  480
# Hudson_0029.vhdr      160      160      160      160      160      160  480
# Hudson_0013.vhdr      160      160      160      160      160      160  480
# Hudson_0028.vhdr      160      160      160      160      160      160  480
# Hudson_0032.vhdr      160      160      160      160      160      160  480
# Hudson_0024.vhdr      160      160      160      160      160      160  480
# Hudson_0015.vhdr      160      160      160      160      160      160  480
# Hudson_0023.vhdr      160      160      160      160      160      160  480
# Hudson_0035.vhdr      160      160      160      160      160      160  480
# Hudson_0019.vhdr      160      160      160      160      160      160  480
# Hudson_0018.vhdr      159      159      159      158      160      160  479
# Hudson_0034.vhdr      160      160      160      160      160      160  480
# Hudson_0022.vhdr      160      160      160      160      160      160  480
# Hudson_0014.vhdr      160      160      160      160      160      160  480
#
#                  right good  bad  ... 3+1_diff-left 3+1_diff-left-good  \
# Hudson_0017.vhdr   480  855  105  ...            80                 68
# Hudson_0021.vhdr   480  837  123  ...            80                 71
# Hudson_0020.vhdr   480  698  262  ...            80                 55
# Hudson_0016.vhdr   480  694  266  ...            80                 56
# Hudson_0031.vhdr   480  723  237  ...            80                 60
# Hudson_0027.vhdr   480  696  264  ...            80                 55
# Hudson_0026.vhdr   240  388   92  ...            40                 32
# Hudson_0030.vhdr   480  632  328  ...            80                 59
# Hudson_0025.vhdr   480  774  186  ...            80                 66
# Hudson_0033.vhdr   480  900   60  ...            80                 73
# Hudson_0029.vhdr   480  598  362  ...            80                 48
# Hudson_0013.vhdr   480  889   71  ...            80                 74
# Hudson_0028.vhdr   480  683  277  ...            80                 57
# Hudson_0032.vhdr   480  802  158  ...            80                 67
# Hudson_0024.vhdr   480  699  261  ...            80                 55
# Hudson_0015.vhdr   480  821  139  ...            80                 66
# Hudson_0023.vhdr   480  689  271  ...            80                 59
# Hudson_0035.vhdr   480  678  282  ...            80                 53
# Hudson_0019.vhdr   480  804  156  ...            80                 65
# Hudson_0018.vhdr   476  671  284  ...            80                 56
# Hudson_0034.vhdr   480  758  202  ...            80                 70
# Hudson_0022.vhdr   480  771  189  ...            80                 68
# Hudson_0014.vhdr   480  676  284  ...            80                 52
#
#                  3+1_diff-good 3+1_diff-left-bad 3+1_diff-bad 3+1_diff-right  \
# Hudson_0017.vhdr           141                12           19             80
# Hudson_0021.vhdr           138                 9           22             80
# Hudson_0020.vhdr           115                25           45             80
# Hudson_0016.vhdr           116                24           44             80
# Hudson_0031.vhdr           120                20           40             80
# Hudson_0027.vhdr           111                25           49             80
# Hudson_0026.vhdr            64                 8           16             40
# Hudson_0030.vhdr           105                21           55             80
# Hudson_0025.vhdr           135                14           25             80
# Hudson_0033.vhdr           149                 7           11             80
# Hudson_0029.vhdr            98                32           62             80
# Hudson_0013.vhdr           147                 6           13             80
# Hudson_0028.vhdr           110                23           50             80
# Hudson_0032.vhdr           130                13           30             80
# Hudson_0024.vhdr           113                25           47             80
# Hudson_0015.vhdr           137                14           23             80
# Hudson_0023.vhdr           120                21           40             80
# Hudson_0035.vhdr           112                27           48             80
# Hudson_0019.vhdr           137                15           23             80
# Hudson_0018.vhdr           115                24           45             80
# Hudson_0034.vhdr           133                10           27             80
# Hudson_0022.vhdr           139                12           21             80
# Hudson_0014.vhdr           112                28           48             80
#
#                  3+1_diff-right-good 3+1_diff-right-bad checksum notes
# Hudson_0017.vhdr                  73                  7        1
# Hudson_0021.vhdr                  67                 13        1
# Hudson_0020.vhdr                  60                 20        1
# Hudson_0016.vhdr                  60                 20        1
# Hudson_0031.vhdr                  60                 20        1
# Hudson_0027.vhdr                  56                 24        1
# Hudson_0026.vhdr                  32                  8        1
# Hudson_0030.vhdr                  46                 34        1
# Hudson_0025.vhdr                  69                 11        1
# Hudson_0033.vhdr                  76                  4        1
# Hudson_0029.vhdr                  50                 30        1
# Hudson_0013.vhdr                  73                  7        1
# Hudson_0028.vhdr                  53                 27        1
# Hudson_0032.vhdr                  63                 17        1
# Hudson_0024.vhdr                  58                 22        1
# Hudson_0015.vhdr                  71                  9        1
# Hudson_0023.vhdr                  61                 19        1
# Hudson_0035.vhdr                  59                 21        1
# Hudson_0019.vhdr                  72                  8        1
# Hudson_0018.vhdr                  59                 21        1
# Hudson_0034.vhdr                  63                 17        1
# Hudson_0022.vhdr                  71                  9        1
# Hudson_0014.vhdr                  60                 20        1
#
# [23 rows x 60 columns]

# %% [markdown]
# ## Final CDA figure from Feldmann-Wustefel 2018
# ### Grand Average

# %%
# 1. Get Grand Average CDA (across subjects)
cda_all = dict()
for cond in cda_dict[list(cda_dict.keys())[0]].keys():
    cda_all[cond] = dict()

    for f in cda_dict.keys():
        if len(cda_dict[f][cond]['left']['good']) > 0:
            cda_dict_cur = (cda_dict[f][cond]['left']['good'] + cda_dict[f][cond]['right']['good'])/2
            cda_all[cond] = np.vstack([cda_all[cond], cda_dict_cur]) if len(cda_all[cond]) else cda_dict_cur
        else:
            print("==== SKIPPED: 0 points! (File: {} - Trigger: {})".format(str(f), str(t)))
            
# 2. Plot Figure #1
plt.figure(figsize=(10, 6), dpi=80)
plt.plot(times, cda_all['1+3_same'].mean(0), label='1+3_same')
plt.plot(times, cda_all['2+2_same'].mean(0), label='2+2_same')
plt.plot(times, cda_all['3+1_same'].mean(0), label='3+1_same')
plt.axvspan(0.3, 0.7, facecolor='pink', edgecolor='none', alpha=.2)
plt.axvspan(1, 1.4, facecolor='pink', edgecolor='none', alpha=.2)
plt.axvline(x=0, color='k', linestyle='--')
plt.axvline(x=0.7, color='k', linestyle='--')
plt.axvline(x=1.5, color='k', linestyle='--')
plt.gca().invert_yaxis()
plt.legend()
plt.ylabel('[μV]')
plt.xlabel('[s]')
plt.show()

# 2. Plot Figure #2
plt.figure(figsize=(10, 6), dpi=80)
plt.plot(times, cda_all['1+3_diff'].mean(0), label='1+3_diff')
plt.plot(times, cda_all['2+2_diff'].mean(0), label='2+2_diff')
plt.plot(times, cda_all['3+1_diff'].mean(0), label='3+1_diff')
plt.axvspan(0.3, 0.7, facecolor='pink', edgecolor='none', alpha=.2)
plt.axvspan(1, 1.4, facecolor='pink', edgecolor='none', alpha=.2)
plt.axvline(x=0, color='k', linestyle='--')
plt.axvline(x=0.7, color='k', linestyle='--')
plt.axvline(x=1.5, color='k', linestyle='--')
plt.gca().invert_yaxis()
plt.legend()
plt.ylabel('[μV]')
plt.xlabel('[s]')
plt.show()

# %%
#====================================
# Save the whole CDA dict.
#====================================
cda_dict['times'] = times
with open("cda_feldmann2018_exp1_goodbad.pkl","wb") as f:
    pickle.dump(cda_dict, f)
